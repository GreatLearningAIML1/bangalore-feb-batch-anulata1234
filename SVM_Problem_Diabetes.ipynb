# %%
#Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read the input file 'Diabetes.csv' using Pandas and check it's column names(1 Marks)

# %%
import pandas as pd
diabetes_df = pd.read_csv("Diabetes.csv")
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
# Eye ball the imported dataset

# %% [markdown]
# ### Check dimension of dataset

# %%
diabetes_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
# (768, 9)

# %% [markdown]
# ### Check distribution of dependent variable, Outcome and plot it (1 Marks)

# %%
diabetes_df_dependent = diabetes_df.drop(columns = 'Outcome')
import seaborn as sns
sns.pairplot(diabetes_df_dependent, diag_kind = "kde")

# %% [markdown]
# ### Out of  768 data points, 500 are labeled as 0 and 268 as 1.
# ### Outcome 0 means No diabetes, outcome 1 means diabetes

# %%
diabetes_df.describe().transpose()
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
# Check data types and info of dataset
print(diabetes_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %% [markdown]
# ### Check data distribution using summary statistics and provide your findings(2 Marks)

# %%
# from the sns plot we can say that there will be  2 mim - 8 max clusters , from the sns plot which is done on the independent variables .
# we can also infer that the glucose and insulin is highly correlated
#

# %% [markdown]
# ### Do correlation analysis and bivariate viualization with Insights(1 Marks)

# %%
diabetes_df.corr()

# plotting done above .

# Glucose and insulin has posiytive and high value of correlation
# Glucose and outcome also has giot high valur of correlation compared to the other pairs
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# #### Do train and test split with stratify sampling on Outcome variable to maintain the distribution of dependent variable(1 Marks)

# %%
from sklearn.model_selection import train_test_split

# To calculate the accuracy score of the model
from sklearn.metrics import accuracy_score, confusion_matrix

target = diabetes_df["Outcome"]
features = diabetes_df.drop(["Outcome"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(features,target, test_size = 0.2, random_state = 10)

# %% [markdown]
# ### Train Support Vector Machine Model(1 Marks)

# %%
from sklearn.svm import SVC

# Building a Support Vector Machine on train data
svc_model = SVC(C= 2.5, kernel='linear', gamma= 1)
svc_model.fit(X_train, y_train)
prediction = svc_model .predict(X_test)
print(svc_model.score(X_train, y_train))
print(svc_model.score(X_test, y_test))
X_train
# Out:
# 0.7736156351791531
# 0.7532467532467533
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 120            0      162             76             56      100  53.2
# 172            2       87              0             23        0  28.9
# 307            0      137             68             14      148  24.8
# 7             10      115              0              0        0  35.3
# 448            0      104             64             37       64  33.6
# 1              1       85             66             29        0  26.6
# 538            0      127             80             37      210  36.3
# 469            6      154             78             41      140  46.1
# 102            0      125             96              0        0  22.5
# 510           12       84             72             31        0  29.7
# 274           13      106             70              0        0  34.2
# 560            6      125             76              0        0  33.8
# ...

# %%
# your insights

# %% [markdown]
# ### Scale the data points using MinMaxScaler ( 1 Marks)

# %%
from sklearn.preprocessing import MinMaxScaler
features = diabetes_df.drop(["Outcome"], axis=1)
scaler = MinMaxScaler()
scaler.fit(features)
# features = scaler.transform(features)
# print(scaler.data_max_)

# features = scaler.transform(X_train)

X_train, X_test, y_train, y_test = train_test_split(features,target, test_size = 0.2, random_state = 10)

X_train_min_max=scaler.transform(X_train)
# Out:
# C:\Users\anusingh\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# ### Fit SVM Model on Scale data and give your observation( 1 Marks)

# %%
from sklearn.svm import SVC

# Building a Support Vector Machine on train data
svc_model = SVC(C= 2.5, kernel='linear', gamma= 1)
svc_model.fit(X_train, y_train)
prediction = svc_model.predict(X_test)
print(svc_model.score(X_train_min_max, y_train))
print(svc_model.score(X_test, y_test))

# minmax scaler has reduced the accuracy
# Out:
# 0.6596091205211726
# 0.7532467532467533

# %% [markdown]
# #we can try increasing either C or gamma to fit a more complex model.

# %% [markdown]
# ### Try improving the model accuracy using C=1000 (1 Marks)

# %%
from sklearn.model_selection import train_test_split

# To calculate the accuracy score of the model
from sklearn.metrics import accuracy_score, confusion_matrix

# target = diabetes_df["Outcome"]
# features = diabetes_df.drop(["Outcome"], axis=1)
# X_train, X_test, y_train, y_test = train_test_split(features,target, test_size = 0.2, random_state = 10)
from sklearn.svm import SVC

# Building a Support Vector Machine on train data
svc_model = SVC(C= 1000, kernel='linear', gamma= 1)
svc_model.fit(X_train, y_train)
prediction = svc_model .predict(X_test)
print(svc_model.score(X_train_min_max, y_train))
print(svc_model.score(X_test, y_test))

# %% [markdown]
# ### Here, increasing C allows us to improve the model, resulting in ??? accuracy.
# ### Let's try to explore different Kernel and C (Bonus for practice)

# %%
import multiprocessing 
from sklearn.model_selection import GridSearchCV

# %%
 param_grid = [    {        
     'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],        
     'C': [ 0.1, 0.2, 0.4, 0.5, 1.0, 1.5, 1.8, 2.0, 2.5, 3.0 ]    } ]

# %%
gs = GridSearchCV(estimator=SVC(), param_grid=param_grid,scoring='accuracy', cv=10, n_jobs=multiprocessing.cpu_count())

# %%
gs.fit(X_train, y_train)

# %%
gs.best_estimator_

# %%
gs.best_score_
